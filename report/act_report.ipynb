# %% [markdown]
# # Act_report
# ### Raghad Alsukhiber

# %% [markdown]
# ## Introduction:
# On this report I’m going to walk through all the insights I came up with on this project wrangling which are five insights, alongside with the visualization plot for each insight with a description below each plot.

# %% [markdown]
# The insights I came up with through this project are:
# #### Insights:
# - which stage is the more popular one?
# - which source people usually use?
# - which name is more used for the dogs?
# - what is the most popular prediction?
# - which rating_numerator are most used on the account?

# %% [markdown]
# ##### First insight:
# - which stage is more popular?

# %% [markdown]
# ![dog_stage.JPG](attachment:dog_stage.JPG)

# %% [markdown]
# As you can see on the above plot I used ‘pie’ plot to visualize the dogs stage and the most common stage is the ‘pupper’ stage with a huge difference.

# %% [markdown]
# ##### Second insight:
# - which source people usually use?

# %% [markdown]
# ![source.JPG](attachment:source.JPG)

# %% [markdown]
# The majority of people use twitter with iPhone devices and the difference is huge.

# %% [markdown]
# ##### Third insight:
# - which name is more used?

# %% [markdown]
# ![dog_name.JPG](attachment:dog_name.JPG)

# %% [markdown]
# There are a lot of dogs with wrong names or unknown names on ‘WeRateDogs’ account.

# %% [markdown]
# ##### Fourth insight:
# - what is the most popular predection?

# %% [markdown]
# ![dog_predection.JPG](attachment:dog_predection.JPG)

# %% [markdown]
# There is a big difference between ‘golden retriever’ and other categories, but the rest of the categories has a slight difference between them.

# %% [markdown]
# ##### Fifth insight:
# - which rating_numerator are most used?

# %% [markdown]
# ![rating.JPG](attachment:rating.JPG)

# %% [markdown]
# The above plot represents the rating numerator for the twitter account and as you can see most of the rating set between (10 to 13), but I think all the dogs should be at least above 9. Don’t you think?
